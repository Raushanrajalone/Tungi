# %% [markdown]
# <a href="https://colab.research.google.com/github/Raushanrajalone/Smart_product_labeling_system/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython import get_ipython
from IPython.display import display
# !pip install opencv-python easyocr pyzbar imutils qrcode[pil] python-barcode
# !pip install labelImg
# !pip install torch torchvision
# !pip install opencv-python easyocr pyzbar imutils qrcode[pil] python-barcode
# !sudo apt-get install -y libzbar0  # For barcode scanning
# !pip install -q opencv-python easyocr pyzbar numpy Pillow
# Install the zbar system library dependency for pyzbar
# !sudo apt-get update
# !apt-get install -y zbar-tools libzbar0
# !pip install -U torch torchvision  # PyTorch base
# !pip install opencv-python-headless matplotlib pandas  # Image processing
# !git clone https://github.com/ultralytics/yolov5  # Official YOLOv5 repo
# %cd yolov5
# !pip install -r requirements.txt
# %cd /content/yolov5
# !ls runs/train/label_defect_v1
# !pip install pyzbar easyocr ultralytics opencv-python-headless matplotlib pillow
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libzbar0 is already the newest version (0.23.92-4build2).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import cv2
import numpy as np
from pyzbar import pyzbar
import easyocr
import re
import time
import os
from PIL import Image
import matplotlib.pyplot as plt
from google.colab import files
import subprocess

# 1. Fixed defect detection function
def reliable_defect_detection(image_path):
    try:
        # Verify model exists
        best_model = "/content/runs/train/label_defect_model/weights/best.pt"
        if not os.path.exists(best_model):
            raise FileNotFoundError(f"Model not found at {best_model}")

        # Create unique output directory
        timestamp = int(time.time())
        output_dir = f"/content/runs/detect/verify_{timestamp}"
        os.makedirs(output_dir, exist_ok=True)

        # Run detection using subprocess to capture errors
        command = [
            "python", "/content/yolov5/detect.py",
            "--weights", best_model,
            "--source", image_path,
            "--conf", "0.4",
            "--save-txt",
            "--save-conf",
            "--project", "/content/runs/detect",
            "--name", f"verify_{timestamp}",
            "--exist-ok"
        ]
        result = subprocess.run(command, capture_output=True, text=True)

        if result.returncode != 0:
            raise RuntimeError(f"Detection failed: {result.stderr}")

        # Process results
        result_files = os.listdir(output_dir)
        result_images = [f for f in result_files if f.endswith('.jpg')]
        defects = []
        result_img = None

        if result_images:
            result_path = os.path.join(output_dir, result_images[0])
            if os.path.exists(result_path):
                result_img = Image.open(result_path)

                # Parse detection results
                txt_files = [f for f in result_files if f.endswith('.txt')]
                if txt_files:
                    with open(os.path.join(output_dir, txt_files[0])) as f:
                        for line in f:
                            parts = line.strip().split()
                            if len(parts) >= 5:  # Ensure valid detection line
                                class_id = int(parts[0])
                                defects.append(["crumpled", "torn", "ink_smear", "misprinted"][class_id])

        return result_img, defects

    except Exception as e:
        print(f"❌ Defect detection error: {str(e)}")
        return None, []

# %%
import os

# Create dataset directories
os.makedirs("/content/dataset/train/images", exist_ok=True)
os.makedirs("/content/dataset/train/labels", exist_ok=True)
os.makedirs("/content/dataset/val/images", exist_ok=True)
os.makedirs("/content/dataset/val/labels", exist_ok=True)

print("Directory structure created!")
# !find /content/dataset -type d
# Out:
# Directory structure created!
# /content/dataset
# /content/dataset/train
# /content/dataset/train/labels
# /content/dataset/train/images
# /content/dataset/val
# /content/dataset/val/labels
# /content/dataset/val/images
# Directory structure created!
# /content/dataset
# /content/dataset/train
# /content/dataset/train/labels
# /content/dataset/train/images
# /content/dataset/val
# /content/dataset/val/labels
# /content/dataset/val/images

# %%
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import random
import cv2
import matplotlib.pyplot as plt
import os

# Faster base label generation
def generate_base_label(device_id, batch_id, rohs=True):
    img = Image.new('RGB', (800, 400), (255, 255, 255))
    draw = ImageDraw.Draw(img)

    try:
        # Use a font that is likely to exist in Colab environments
        font_path = "/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf"
        if not os.path.exists(font_path):
             font_path = "/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf"
             if not os.path.exists(font_path):
                 font = ImageFont.load_default()
             else:
                 font = ImageFont.truetype(font_path, 24)
        else:
            font = ImageFont.truetype(font_path, 24)

    except Exception as e:
        print(f"Could not load truetype font, using default: {e}")
        font = ImageFont.load_default()

    # Device information
    draw.text((50, 50), f"Device ID: {device_id}", fill="black", font=font)
    draw.text((50, 100), f"Batch ID: {batch_id}", fill="black", font=font)

    # Compliance status
    status = "RoHS Compliant ✅" if rohs else "Non-RoHS ⚠️"
    color = "green" if rohs else "red"
    draw.text((50, 150), status, fill=color, font=font)

    # Barcode simulation
    for i in range(15):
        width = random.randint(10, 30)
        x = 60 + i * 50
        draw.rectangle([x, 200, x + width, 300], fill="black")

    # QR code simulation
    for i in range(5):
        for j in range(5):
            if random.random() > 0.4:
                draw.rectangle([450 + i*60, 50 + j*60, 450 + i*60 + 40, 50 + j*60 + 40], fill="black")

    return img

# Optimized defect functions
def add_crumple_effect(img):
    img = np.array(img)
    h, w = img.shape[:2]
    scale = 0.05
    dx = scale * np.random.randn(h, w).astype(np.float32)
    dy = scale * np.random.randn(h, w).astype(np.float32)
    map_x = (np.tile(np.arange(w), (h, 1)) + dx * 50).astype(np.float32) # Ensure float32 type
    map_y = (np.tile(np.arange(h), (w, 1)).T + dy * 50).astype(np.float32) # Ensure float32 type
    # Use the second form of remap: two single-channel maps of type CV_32FC1 (np.float32)
    distorted = cv2.remap(img, map_x, map_y, cv2.INTER_LINEAR)
    return Image.fromarray(distorted)


def add_tear_effect(img):
    draw = ImageDraw.Draw(img, 'RGBA')
    w, h = img.size
    y = random.randint(100, h-100)
    for x in range(0, w, 10):
        y += random.randint(-15, 15)
        draw.line([(x, y), (x+10, y)], fill=(100,100,100,200), width=3)
    return img

def add_ink_smear(img):
    draw = ImageDraw.Draw(img, 'RGBA')
    w, h = img.size
    start = (random.randint(100, w-100), random.randint(100, h-100))
    for _ in range(3):
        end = (start[0] + random.randint(-80,80), start[1] + random.randint(-80,80))
        draw.line([start, end], fill=(0,0,0,150), width=random.randint(10,20))
        start = end
    return img

def add_misprint_effect(img):
    # Random color shift
    r, g, b = img.split()
    r = r.point(lambda p: p * random.uniform(0.7, 1.3))
    g = g.point(lambda p: p * random.uniform(0.7, 1.3))
    b = b.point(lambda p: p * random.uniform(0.7, 1.3))
    img = Image.merge('RGB', (r, g, b))

    # Add missing text
    if random.random() > 0.3:
        draw = ImageDraw.Draw(img)
        draw.rectangle([50, 50, 300, 180], fill="white")

    return img

# Generate dataset
def generate_dataset_samples(num_images=200, split_ratio=0.8):
    class_map = {0: "crumpled", 1: "torn", 2: "ink_smear", 3: "misprinted"}

    for i in range(num_images):
        # Create base label
        device_id = f"DVC{random.randint(10000, 99999)}"
        batch_id = f"BATCH-{random.randint(1000, 9999)}"
        base_img = generate_base_label(device_id, batch_id, rohs=random.random() > 0.3)

        # Determine split
        split = 'train' if i < num_images * split_ratio else 'val'

        # Apply defects or keep good
        if random.random() < 0.8:  # 80% defective
            defect_type = random.randint(0, 3)
            defect_name = class_map[defect_type]

            if defect_type == 0: img = add_crumple_effect(base_img)
            elif defect_type == 1: img = add_tear_effect(base_img)
            elif defect_type == 2: img = add_ink_smear(base_img)
            else: img = add_misprint_effect(base_img)

            # Save image
            img_path = f"/content/dataset/{split}/images/label_{i}_{defect_name}.jpg"
            img.save(img_path)

            # Create annotation
            label_path = f"/content/dataset/{split}/labels/label_{i}_{defect_name}.txt"
            # The bounding box coordinates (0.5 0.5 0.9 0.9) seem generic.
            # You might want to calculate more accurate bounding boxes for the defect area
            # or the label as a whole, depending on your YOLO training objective.
            # For this fix, we keep the generic box.
            with open(label_path, 'w') as f:
                f.write(f"{defect_type} 0.5 0.5 0.9 0.9\n")
        else:  # 20% good
            img_path = f"/content/dataset/{split}/images/label_{i}_good.jpg"
            base_img.save(img_path)

    print(f"Generated {num_images} samples")

# Generate dataset
generate_dataset_samples(200)

# Verify creation
print("\nDataset verification:")
print(f"Train images: {len(os.listdir('/content/dataset/train/images'))}")
print(f"Train labels: {len(os.listdir('/content/dataset/train/labels'))}")
print(f"Val images: {len(os.listdir('/content/dataset/val/images'))}")
print(f"Val labels: {len(os.listdir('/content/dataset/val/labels'))}")
# Out:
# Generated 200 samples
#
# Dataset verification:
# Train images: 291
# Train labels: 233
# Val images: 72
# Val labels: 61
# Generated 200 samples
#
# Dataset verification:
# Train images: 395
# Train labels: 321
# Val images: 95
# Val labels: 80

# %%
# Create dataset configuration
yaml_content = """
train: /content/dataset/train/images
val: /content/dataset/val/images
nc: 4
names:
  - crumpled
  - torn
  - ink_smear
  - misprinted
"""

with open("/content/dataset/dataset.yaml", "w") as f:
    f.write(yaml_content.strip())

print("\ndataset.yaml created:")
# !cat /content/dataset/dataset.yaml
# Out:
# dataset.yaml created:
# train: /content/dataset/train/images
# val: /content/dataset/val/images
# nc: 4
# names:
#   - crumpled
#   - torn
#   - ink_smear
#   - misprinted
# dataset.yaml created:
# train: /content/dataset/train/images
# val: /content/dataset/val/images
# nc: 4
# names:
#   - crumpled
#   - torn
#   - ink_smear
#   - misprinted

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5/yolov5
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5/yolov5/yolov5

# %%
# Train with explicit path handling
# !python /content/yolov5/train.py \
    --weights yolov5s.pt \
    --img 640 \
    --batch 32 \
    --epochs 20 \
    --data /content/dataset/dataset.yaml \
    --project /content/runs/train \
    --name label_defect_model \
    --exist-ok \
    --cache ram \
    --workers 4
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-12 04:50:06.990062: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752295807.011186    7156 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752295807.017590    7156 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# Verify model creation
model_dir = "/content/runs/train/label_defect_model/weights"
if os.path.exists(model_dir):
    print("\n✅ Model training successful!")
    print("Model files:")
    # !ls -lh {model_dir}
else:
    print("\n❌ Model training failed - check logs above")
# Out:
# ✅ Model training successful!
# Model files:
# total 28M
# -rw-r--r-- 1 root root 14M Jul 12 04:52 best.pt
# -rw-r--r-- 1 root root 14M Jul 12 04:52 last.pt
#
# ✅ Model training successful!
# Model files:
# total 28M
# -rw-r--r-- 1 root root 14M Jul 12 05:00 best.pt
# -rw-r--r-- 1 root root 14M Jul 12 05:00 last.pt

# %%
import os
import time
from PIL import Image
from IPython.display import display
from google.colab import files
import torch

def reliable_defect_detection(image_path, conf_thres=0.25, imgsz=640):
    """Robust defect detection with automatic device selection"""
    # Auto-select device (GPU if available, else CPU)
    device = "0" if torch.cuda.is_available() else "cpu"

    # Verify model exists
    best_model = "/content/runs/train/label_defect_model/weights/best.pt"
    if not os.path.exists(best_model):
        # Add a print statement to help debug if the file is truly missing
        model_weight_dir = os.path.dirname(best_model)
        print(f"Debug: Checking directory {model_weight_dir}")
        if os.path.exists(model_weight_dir):
            print(f"Debug: Contents of {model_weight_dir}: {os.listdir(model_weight_dir)}")
        else:
            print(f"Debug: Model directory {model_weight_dir} does not exist.")
        raise FileNotFoundError("❌ Trained model not found. Train first with train.py!")

    # Create unique output directory
    timestamp = int(time.time())
    output_dir = f"/content/runs/detect/verify_{timestamp}"
    os.makedirs(output_dir, exist_ok=True)

    # Run detection
    # Note: Using subprocess might be more robust for capturing errors
    # but for simplicity in Colab, the shell execution is often used.
    # If using subprocess, ensure commands and arguments are correctly formatted.
    # !python /content/yolov5/detect.py \
      --weights {best_model} \
      --source "{image_path}" \
      --conf {conf_thres} \
      --imgsz {imgsz} \
      --device {device} \
      --augment \
      --save-txt \
      --save-conf \
      --project /content/runs/detect \
      --name verify_{timestamp} \
      --exist-ok

    # Process results
    detection_dir = f"/content/runs/detect/verify_{timestamp}"
    defects = []

    # Check for labels
    if os.path.exists(f"{detection_dir}/labels"):
        for label_file in os.listdir(f"{detection_dir}/labels"):
            if label_file.endswith(".txt"):
                with open(f"{detection_dir}/labels/{label_file}") as f:
                    for line in f:
                        class_id = int(line.split()[0])
                        defects.append(["crumpled", "torn", "ink_smear", "misprinted"][class_id])

    # Display results
    result_image_path = None
    for ext in ['.jpg', '.png', '.jpeg']:
        possible_path = f"{detection_dir}/{os.path.splitext(os.path.basename(image_path))[0]}{ext}"
        if os.path.exists(possible_path):
            result_image_path = possible_path
            break

    if result_image_path:
        result_img = Image.open(result_image_path)
        display(result_img)
    else:
        print(f"⚠️ No result image found in {detection_dir}")
        # Try to find any image file in the directory
        for file in os.listdir(detection_dir):
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                result_img = Image.open(f"{detection_dir}/{file}")
                display(result_img)
                break
        else:
            print("No images generated in output directory")

    return list(set(defects))  # Return unique defects

# Upload and test with automatic filename cleaning
print("🔼 Please upload your image:")
uploaded = files.upload()
if uploaded:
    original_name = list(uploaded.keys())[0]
    clean_name = original_name.replace(" ", "_").replace("(", "").replace(")", "")
    if original_name != clean_name:
        os.rename(original_name, clean_name)

    print(f"\n🔍 Analyzing {clean_name}...")
    print(f"⚙️ Using {'GPU' if torch.cuda.is_available() else 'CPU'} for detection")
    # Call the function
    defects = reliable_defect_detection(clean_name)
    print(f"\n✅ Detected defects: {defects if defects else 'None'}")
else:
    print("\n❌ No file uploaded!")
# Out:
# 🔼 Please upload your image:
#      <input type="file" id="files-df376354-6c8e-4b27-8ffc-2f421c8d88c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df376354-6c8e-4b27-8ffc-2f421c8d88c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import random
import os

def generate_verifiable_label(save_path="test_label.png"):
    """Generate a label that will pass all verification checks"""
    # 1. Create blank image (higher resolution helps OCR)
    img = Image.new('RGB', (1200, 600), (255, 255, 255))
    draw = ImageDraw.Draw(img)

    # 2. Use bold font for better OCR
    try:
        font_large = ImageFont.truetype("Arial Bold.ttf", 36)
        font_small = ImageFont.truetype("Arial.ttf", 24)
    except:
        # Fallback fonts
        font_large = ImageFont.load_default()
        font_small = ImageFont.load_default()

    # 3. Add required metadata with clear formatting
    device_id = f"DVC-{random.randint(10000, 99999)}"
    batch_id = f"BATCH-{random.randint(1000, 9999)}"

    # Important: Use consistent label formats
    draw.text((100, 100), "DEVICE ID:", fill="black", font=font_large)
    draw.text((400, 100), device_id, fill="blue", font=font_large)

    draw.text((100, 180), "BATCH ID:", fill="black", font=font_large)
    draw.text((400, 180), batch_id, fill="blue", font=font_large)

    # 4. Add RoHS compliance with icon
    rohs_compliant = random.choice([True, False])
    status = "ROHS COMPLIANT: YES ✅" if rohs_compliant else "ROHS COMPLIANT: NO ❌"
    draw.text((100, 260), status, fill="green" if rohs_compliant else "red", font=font_large)

    # 5. Add scannable barcode (simple version)
    for i in range(20):
        width = random.randint(15, 40)
        x = 100 + i * 55
        draw.rectangle([x, 400, x + width, 550], fill="black")

    # 6. Add subtle defect (optional)
    if random.choice([True, False]):
        draw.rectangle([800, 100, 1100, 300], outline="red", width=5)
        draw.text((850, 150), "SIMULATED DEFECT", fill="red", font=font_large)

    # 7. Save as PNG for better quality
    img.save(save_path, dpi=(300, 300))
    print(f"Generated verifiable label: {save_path}")
    display(img)
    return save_path

# Generate and test immediately
test_image = generate_verifiable_label("verified_label.png")
# Out:
# Generated verifiable label: verified_label.png
# <PIL.Image.Image image mode=RGB size=1200x600>
